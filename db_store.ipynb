# %%
import faiss
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_openai import OpenAIEmbeddings

# %%
api_key = "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"

# %%
embeddings_model = OpenAIEmbeddings(model = 'text-embedding-3-small', api_key = api_key)

db = FAISS(
    embedding_function=embeddings_model,
    index=faiss.IndexFlatL2(1536),
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
# %store -r crawled_data

# %%
len(crawled_data)
# Out:
# 215

# %%
crawled_data[0]['info']['description']['menu']+' '+crawled_data[0]['info']['description']['review']
# Out:
# "1. 메뉴목록: B 코스 (1인) 2인이상 주문가능\n대표\n밀푀유나베, 연어세비체, 관자버터구이, 후토마끼, 새우오드볼, 날치알마끼, 참치타다끼\n25,900원\nA 코스 (1인) 2인이상 주문가능\n밀푀유나베, 연어세비체, 새우오드볼,날치알마끼,홍합찜, 모듬초밥\n19,900원\nC 코스 (1인) 2인이상 주문가능\n밀푀유나베, 연어세비체, 새우오드볼, 홍합찜, 날치알마끼, 관자버터구이,모듬초밥, 사시미\n34,900원\n오늘의초밥\n모듬초밥11P, 반우동, 감자고로케\n15,000원\n특선모듬초밥\n모듬초밥15P, 반우동, 감자고로케\n22,000원\n활어모듬초밥\n활어초밥 10P, 반우동, 감자고로케\n21,000원\n그릴모듬초밥\n그릴모듬초밥12P, 반우동, 감자고로케\n21,000원\n정식A세트\n초밥6P,사시미6P,육회,육회군함,반우동,튀김\n20,000원\n정식B세트\n초밥8P,사시미8P,육회,육회군함,반우동,감자고로케\n27,000원\n채소 불초밥\n채소불초밥12p + 우동 + 감자고로케\n20,000원\n런치초밥\n10,000원\n런치스페셜초밥\n15,000원\n나만의초밥A\n내가 원하는 초밥을 내맘대로 !! 총 12P를 마음껏 즐기세요\n19,000원\n나만의초밥B\n23,000원\n나만의초밥C\n27,000원\n메뉴 항목과 가격은 각 매장의 사정에 따라 기재된 내용과 다를 수 있습니다. 2. 리뷰목록: ['네이버지도로 찾아서 갔는데 생각보다 엄청 만족스러운 식사였어요! A코스 19900원인데 두명이서 모둠초밥 밀푀유나베 연어샐러드 홍합 …등등 많은 종류의 음식을 먹어볼수있단 점이 좋았어요 ㅎㅎ 초밥 퀄리티도 좋았고 재방문의사도 있습니다!', '친구랑 오랜만에 만나서 밥 먹는데, 코스로 나와서 너무 좋고 자리도 아늑하고 좋네요!! 그리고 음식이 너무 맛있습니다앙 ◡̈♥︎', '예약하고 가서 웨이팅 5분정도 했구 밥 너무 맛있고 좋았어요! 리뷰 이벤트로 주신 초밥도 그렇구 상태도 다 좋고 맛나게 잘 먹고 갑니다! 무엇보다 가게가 깔끔하고
# ...

# %%
ex_crawled_data = crawled_data[:2]

# %%
crawled_data[0]['info']
# Out:
# {'restraunt_name': '스시앤',
#  'address': '서울 마포구 동교로 148 1층',
#  'phone_num': '0507-1496-4456',
#  'open_hours': '수\n11:00 - 01:20\n01:00 라스트오더목\n11:00 - 01:20\n01:00 라스트오더금\n11:00 - 01:20\n01:00 라스트오더토\n11:00 - 01:20\n01:00 라스트오더일\n11:00 - 01:20\n01:00 라스트오더월\n11:00 - 01:00\n00:40 라스트오더화\n11:00 - 01:20\n01:00 라스트오더',
#  'website': 'https://map.naver.com/p/search/%ED%99%8D%EB%8C%80%EC%9E%85%EA%B5%AC%20%EC%9D%8C%EC%8B%9D%EC%A0%90/place/1381414543?c=15.00,0,0,0,dh&placePath=%3Fentry%253Dbmp',
# ...

# %%
crawled_data[0]['info']['description']['review']
# Out:
# "2. 리뷰목록: ['네이버지도로 찾아서 갔는데 생각보다 엄청 만족스러운 식사였어요! A코스 19900원인데 두명이서 모둠초밥 밀푀유나베 연어샐러드 홍합 …등등 많은 종류의 음식을 먹어볼수있단 점이 좋았어요 ㅎㅎ 초밥 퀄리티도 좋았고 재방문의사도 있습니다!', '친구랑 오랜만에 만나서 밥 먹는데, 코스로 나와서 너무 좋고 자리도 아늑하고 좋네요!! 그리고 음식이 너무 맛있습니다앙 ◡̈♥︎', '예약하고 가서 웨이팅 5분정도 했구 밥 너무 맛있고 좋았어요! 리뷰 이벤트로 주신 초밥도 그렇구 상태도 다 좋고 맛나게 잘 먹고 갑니다! 무엇보다 가게가 깔끔하고 사람 많았는데도 다들 친절하셨습니당 😊', '늦은밤 갑자기 스시가 먹고싶어서 열심히 검색해서 찾아갔어요~ 사장님 너무 친절하시고 초밥도 넘 맛있네요👍🏻👍🏻👍🏻 저희가 주문을 잘못해서 세트초밥을 못먹었지만 이건 담에 방문해서 꼭!!! 먹어보려고용~ 배달도 가능한거 같아서 집에서도 주문해먹어도 좋을거같아용🙂', '크리스마스 이브에 언니랑 보내고 싶어서 찾게되서 방문했는뎅\\n샤브샤브에 회도 나오고 구성이 좋내용~~\\n정말 배터지게 잘먹었습니다^^', '초반에 이렇게 샐러드 나오다가 스시, 마끼도 나오는데 이정도 가격에 코스처럼 먹을 수 있어서 좋아요!! 무엇보다 사장님 서비스가 너무 좋아서… 추천해요🎄⭐️', '둘이서 A코스에 가라아게 주문해서 먹었어요! 너무 맛있더라구요.. 재료도 신선하고 양도 많았어요!! 양이 부족할까 싶어서 사이드로 가라아게 시킨 건데 가라아게 안 시켰어도 충분한 양이었을 것 같더라구요ㅎㅎ 진짜 가성비 좋습니다 잘 먹었습니당 :)']"

# %%
len(db.docstore.dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 len(db.docstore.dict)
#
# AttributeError: 'InMemoryDocstore' object has no attribute 'dict'

# %%
{key: value for key, value in crawled_data[0]['info'].items() if key != 'description'}
# Out:
# {'restraunt_name': '스시앤',
#  'address': '서울 마포구 동교로 148 1층',
#  'phone_num': '0507-1496-4456',
#  'open_hours': '수\n11:00 - 01:20\n01:00 라스트오더목\n11:00 - 01:20\n01:00 라스트오더금\n11:00 - 01:20\n01:00 라스트오더토\n11:00 - 01:20\n01:00 라스트오더일\n11:00 - 01:20\n01:00 라스트오더월\n11:00 - 01:00\n00:40 라스트오더화\n11:00 - 01:20\n01:00 라스트오더',
#  'website': 'https://map.naver.com/p/search/%ED%99%8D%EB%8C%80%EC%9E%85%EA%B5%AC%20%EC%9D%8C%EC%8B%9D%EC%A0%90/place/1381414543?c=15.00,0,0,0,dh&placePath=%3Fentry%253Dbmp'}

# %%
crawled_data['info']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 crawled_data['info'][0]
#
# TypeError: list indices must be integers or slices, not str

# %%
crawled_data[0]['info']
# Out:
# {'restraunt_name': '스시앤',
#  'address': '서울 마포구 동교로 148 1층',
#  'phone_num': '0507-1496-4456',
#  'open_hours': '수\n11:00 - 01:20\n01:00 라스트오더목\n11:00 - 01:20\n01:00 라스트오더금\n11:00 - 01:20\n01:00 라스트오더토\n11:00 - 01:20\n01:00 라스트오더일\n11:00 - 01:20\n01:00 라스트오더월\n11:00 - 01:00\n00:40 라스트오더화\n11:00 - 01:20\n01:00 라스트오더',
#  'website': 'https://map.naver.com/p/search/%ED%99%8D%EB%8C%80%EC%9E%85%EA%B5%AC%20%EC%9D%8C%EC%8B%9D%EC%A0%90/place/1381414543?c=15.00,0,0,0,dh&placePath=%3Fentry%253Dbmp',
# ...

# %%
for i in range(len(crawled_data)):
    db.add_texts(['0. 가게명: '+crawled_data[i]['info']['restraunt_name']+' '+crawled_data[i]['info']['description']['menu']+' '+crawled_data[i]['info']['description']['review']], metadatas=[{key: value for key, value in crawled_data[i]['info'].items() if key != 'description'}], ids=[i+1])

# %%
db.add_texts([], metadatas=[])

# %%
len(db.docstore._dict.items())
# Out:
# 215

# %%
db.docstore._dict
# Out:
# {1: Document(metadata={'restraunt_name': '스시앤', 'address': '서울 마포구 동교로 148 1층', 'phone_num': '0507-1496-4456', 'open_hours': '수\n11:00 - 01:20\n01:00 라스트오더목\n11:00 - 01:20\n01:00 라스트오더금\n11:00 - 01:20\n01:00 라스트오더토\n11:00 - 01:20\n01:00 라스트오더일\n11:00 - 01:20\n01:00 라스트오더월\n11:00 - 01:00\n00:40 라스트오더화\n11:00 - 01:20\n01:00 라스트오더', 'website': 'https://map.naver.com/p/search/%ED%99%8D%EB%8C%80%EC%9E%85%EA%B5%AC%20%EC%9D%8C%EC%8B%9D%EC%A0%90/place/1381414543?c=15.00,0,0,0,dh&placePath=%3Fentry%253Dbmp'}, page_content="0. 가게명: 스시앤 1. 메뉴목록: B 코스 (1인) 2인이상 주문가능\n대표\n밀푀유나베, 연어세비체, 관자버터구이, 후토마끼, 새우오드볼, 날치알마끼, 참치타다끼\n25,900원\nA 코스 (1인) 2인이상 주문가능\n밀푀유나베, 연어세비체, 새우오드볼,날치알마끼,홍합찜, 모듬초밥\n19,900원\nC 코스 (1인) 2인이상 주문가능\n밀푀유나베, 연어세비체, 새우오드볼, 홍합찜, 날치알마끼, 관자버터구이,모듬초밥, 사시미\n34,900원\n오늘의초밥\n모듬초밥11P, 반우동, 감자고로케\n15,000원\n특선모듬초밥\n모듬초밥15P, 반우동, 감자고로케\n22,000원\n활어모듬초밥\n활어초밥 10P, 반우동, 감자고로케\n21,000원\n그릴모듬초밥\n그릴모듬초밥12P, 반우동, 감자고로케\n21,000원\n정식A세트\n초밥6P,사시미6P,육회,육회군함,반우동,튀김\n20,000원\n정식B세트\n초밥8P,사시미8P,육회,육회군함,반우동
# ...

# %%
db.save_local("naver_hongdae")

# %%
db = db.load_local("naver_hongdae", embeddings_model, allow_dangerous_deserialization=True)

# %%
db.search("추울 때 먹는 음식", search_type='mmr', k=5)
# Out:
# [Document(metadata={'restraunt_name': '남북통일', 'address': '서울 마포구 동교로18길 37', 'phone_num': '02-3141-4113', 'open_hours': '목\n11:00 - 21:30금\n11:00 - 21:30토\n11:00 - 21:30일\n정기휴무 (매주 일요일)월\n11:00 - 21:30화\n11:00 - 21:30수\n11:00 - 21:30', 'website': 'https://map.naver.com/p/search/%ED%99%8D%EB%8C%80%EC%9E%85%EA%B5%AC%20%EC%9D%8C%EC%8B%9D%EC%A0%90/place/11710184?c=15.00,0,0,0,dh&placePath=%3Fentry%253Dbmp'}, page_content="0. 가게명: 남북통일 1. 메뉴목록: 보쌈\n35,000원\n떡만두국\n11,000원\n찐만두\n11,000원\n닭곰탕\n11,000원\n사골칼국수\n11,000원\n녹두빈대떡\n11,000원\n칼만두국\n11,000원\n닭칼국수\n11,000원\n만두전골 대\n52,000원\n만두전골 중\n39,000원\n만두전골 소\n26,000원\n사리/볶음밥\n3,000원\n메뉴 항목과 가격은 각 매장의 사정에 따라 기재된 내용과 다를 수 있습니다. 2. 리뷰목록: ['추운 겨울 만두전골 먹고 싶어 검색했는데 맨 위에 뜬 이곳🙂\\n정말 맛있어요. 만두가 특별하고 기본으로 나오는 칼국수 마저 너무 쫄깃💗 바글바글 끓으면 꼭 국물 한숟갈 해보세요,, 캬~\\n다음엔 볶음밥 사리추가 하고 싶어요ㅋㅋ\\n제 남자친구는 빈대떡이 최고라고 쌍따봉👍', '오랜만에 방문\\n만두전골 국물이 시원하고 맛있어요~\\n빈대떡 최고~~~', '동내주민으로 4년만에 방문한거 같아요\\n좌식에서 입식으로 바뀌었네요\\n그리고 사장님도 바뀌신거 같아요.\\n예전보다 간이 좀 쎄네요! 번창하세요~', '지인들에게 한번씩은 꼭 말해주는 곳이에요. 저도
# ...
